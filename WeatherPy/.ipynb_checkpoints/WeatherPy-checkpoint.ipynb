# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#List to store values
Lat = 0
Lng = 0
Max_Temp = 0
Humidity = 0
Cloudiness = 0
Wind_Speed = 0
Country = ""
Date = ""

City_Weather_df= pd.DataFrame({"City": cities,
                               "Lat": Lat,
                               "Lng": Lng,
                               "Max Temp": Max_Temp,
                               "Humidity": Humidity,
                               "Cloudiness": Cloudiness,
                               "Wind Speed": Wind_Speed,
                               "Country": Country,
                               "Date": Date})

#Loop through cities 
#Incorporate a try-except to skip any cities that are missing a data point.

print(f"Beginning Data Retrieval")
print(f"-----------------------------")
    
for index in range(len(City_Weather_df)):
    city=City_Weather_df.loc[index, "City"]
    #URL to query the api data
    query_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    response = requests.get(query_url).json()
        
    try: 
        print(f"Processing Record {index}: {response['name']}")
        City_Weather_df.loc[index, "City"] = response ["name"]
        City_Weather_df.loc[index, "Lat"] = response ["coord"]["lat"]
        City_Weather_df.loc[index, "Lng"] = response ["coord"]["lon"]
        City_Weather_df.loc[index, "Max Temp"] = response ["main"]["temp_max"]
        City_Weather_df.loc[index, "Humidity"] = response ["main"]["humidity"]
        City_Weather_df.loc[index, "Cloudiness"] = response ["clouds"]["all"]
        City_Weather_df.loc[index, "Wind Speed"] = response ["wind"]["speed"]
        City_Weather_df.loc[index, "Country"] = response ["sys"]["country"]
        City_Weather_df.loc[index, "Date"] = response ["dt"]
        
    except (KeyError, IndexError):
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0: Salinas
# Processing Record 1: Necochea
# Processing Record 2: Rikitea
# Processing Record 3: Ushuaia
# Processing Record 4: Chui
# Processing Record 5: Chernyshevsk
# Processing Record 6: Busselton
# Processing Record 7: Khatanga
# Processing Record 8: Cherskiy
# Processing Record 9: Khanbari
# Processing Record 10: Krasnyy Chikoy
# Processing Record 11: Olafsvik
# Processing Record 12: Albany
# Processing Record 13: Kaitangata
# City not found. Skipping...
# Processing Record 15: Hobart
# Processing Record 16: Saint George
# Processing Record 17: Vaini
# Processing Record 18: Severo-Kuril'sk
# Processing Record 19: New Norfolk
# Processing Record 20: Malanje
# Processing Record 21: Hermanus
# Processing Record 22: Bataiporã
# Processing Record 23: Richards Bay
# Processing Record 24: Ribeira Grande
# Processing Record 25: Elko
# Processing Record 26: Butaritari
# Processing Record 27: Padang
# Processing Record 28: Muncar
# Processing Record 29: Punta Arenas
# Processing Record 30: Vostok
# Processing Record 31: Nikolskoye
# Processing Record 32: Bredasdorp
# Processing Record 33: Port Lincoln
# Processing Record 34: Bereda
# Processing Record 35: Port Alfred
# Processing Record 36: Puerto Ayora
# Processing Record 37: Souillac
# Processing Record 38: Jalu
# Processing Record 39: Balsas
# Processing Record 40: Egvekinot
# Processing Record 41: Isangel
# Processing Record 42: Mehamn
# Processing Record 43: Saint-Pierre
# Processing Record 44: Nome
# Processing Record 45: Acurenam
# Processing Record 46: Fortuna
# Processing Record 47: Pisco
# Processing Record 48: Camacha
# Processing Record 49: Chokurdakh
# Processing Record 50: Bluff
# Processing Record 51: Suntar
# Processing Record 52: Mar del Plata
# Processing Record 53: Saint-Philippe
# Processing Record 156: Salalah
# Processing Record 157: Kenora
# Processing Record 158: Winnemucca
# Processing Record 159: Inhapi
# Processing Record 160: Ilulissat
# Processing Record 161: Dingzhou
# Processing Record 162: Saskylakh
# Processing Record 163: Vanavara
# Processing Record 164: Teluknaga
# Processing Record 165: Polyarnyye Zori
# Processing Record 166: Atbasar
# Processing Record 167: Laas
# Processing Record 168: Rewa
# Processing Record 169: Coquimbo
# Processing Record 170: Ankang
# Processing Record 171: Vuktyl
# Processing Record 172: Djibouti
# Processing Record 173: Hilton Head
# Processing Record 174: Thompson
# City not found. Skipping...
# Processing Record 176: Xining
# Processing Record 177: Kirs
# Processing Record 178: Lüderitz
# Processing Record 179: Santa María del Oro
# Processing Record 180: Alofi
# Processing Record 181: Guerrero Negro
# Processing Record 182: Lorengau
# City not found. Skipping...
# Processing Record 184: Rawson
# Processing Record 185: Tuktoyaktuk
# Processing Record 186: Nikkō
# Processing Record 187: Delījān
# City not found. Skipping...
# Processing Record 189: La Libertad
# Processing Record 190: Ormara
# Processing Record 191: Carnarvon
# Processing Record 192: Assiut
# Processing Record 193: Kenai
# Processing Record 194: Grand-Lahou
# Processing Record 195: Tasiilaq
# Processing Record 196: Port Macquarie
# City not found. Skipping...
# Processing Record 198: Bahsūma
# Processing Record 199: Gáldar
# Processing Record 200: Saint-François
# Processing Record 201: Hirara
# Processing Record 202: Verāval
# Processing Record 203: Hong Kong
# Processing Record 204: Imbituba
# Processing Record 205: Launceston
# Processing Record 206: Sisimiut
# Processing Record 207: Bathsheba
# City not found. Skipping...
# Processing Record 209: Roald
# Processing Record 210: Asău
# City not found. Skipping...
# Processing Record 212: Kysyl-Syr
# Processing Record 213: Chapais
# Processing Record 214: Puerto Escondido
# Processing Record 215: Acarí
# Processing Record 216: Hasaki
# Processing Record 217: Gombe
# Processing Record 218: Ahipara
# City not found. Skipping...
# Processing Record 220: Arraial do Cabo
# Processing Record 221: Manicoré
# Processing Record 222: Kaduqli
# Processing Record 223: Coaticook
# City not found. Skipping...
# Processing Record 225: Ürümqi
# City not found. Skipping...
# Processing Record 227: Samarai
# Processing Record 228: Otavi
# City not found. Skipping...
# Processing Record 230: Cabo San Lucas
# Processing Record 231: Husavik
# Processing Record 232: Srednekolymsk
# Processing Record 233: Taebla
# Processing Record 234: George Town
# Processing Record 235: Zárate
# Processing Record 236: Sakakah
# Processing Record 237: Longyearbyen
# Processing Record 238: Poum
# Processing Record 239: Redwater
# Processing Record 240: Vao
# Processing Record 241: Krasnosel'kup
# Processing Record 242: Chamba
# Processing Record 243: Mahébourg
# Processing Record 244: Morat
# Processing Record 245: Leningradskiy
# Processing Record 246: Caravelas
# Processing Record 247: Bishoftu
# Processing Record 248: Cayenne
# Processing Record 249: Ruzsa
# Processing Record 250: Castro
# Processing Record 251: Cedar Mill
# Processing Record 252: Mariinsk
# Processing Record 253: Colinas
# Processing Record 254: Unaí
# Processing Record 255: Nabire
# Processing Record 256: Road Town
# Processing Record 557: Nerchinskiy Zavod
# Processing Record 558: Vyazemskiy
# Processing Record 559: Ancud
# Processing Record 560: Taoudenni
# Processing Record 561: Nyimba
# Processing Record 562: Nemuro
# Processing Record 563: Erenhot
# Processing Record 564: Visby
# Processing Record 565: Biaora
# City not found. Skipping...
# Processing Record 567: Talnakh
# Processing Record 568: Solnechnyy
# Processing Record 569: Belyy Yar
# Processing Record 570: Samaná
# Processing Record 571: Pumiao
# Processing Record 572: San Ramon
# Processing Record 573: Belize
# City not found. Skipping...
# Processing Record 575: Armidale
# Processing Record 576: Sol'-Iletsk
# Processing Record 577: Baharly
# Processing Record 578: Awjilah
# Processing Record 579: Mandiana
# Processing Record 580: Vershino-Darasunskiy
# Processing Record 581: Ekibastuz
# Processing Record 582: Chato
# Processing Record 583: Izhma
# Processing Record 584: Santa Cruz de la Sierra
# Processing Record 585: Camas
# Processing Record 586: Ponta Delgada
# Processing Record 587: Oktyabr'skoye
# Processing Record 588: Saldanha
# Processing Record 589: Yerbogachën
# Processing Record 590: Sarakhs
# Processing Record 591: Lewisporte
# Processing Record 592: Billings Metropolitan Area
# Processing Record 593: Labuhan
# Processing Record 594: Huntington
# Processing Record 595: Tyazhinskiy
# City not found. Skipping...
# Processing Record 597: Rāwah
# Processing Record 598: Choya
# Processing Record 599: North Bend
# Processing Record 600: Andenes
# Processing Record 601: Pimenta Bueno
# Processing Record 602: Kirakira
# Processing Record 603: Domingos Martins
# City not found. Skipping...
# Processing Record 605: Kismayo
# City not found. Skipping...
# Processing Record 607: Khartoum
# Processing Record 608: Port Elizabeth
# Processing Record 609: Mangaldai
# Processing Record 610: Gushikawa
# City not found. Skipping...
# Processing Record 612: Conakry
# Processing Record 613: Oussouye
# Processing Record 614: Lavrentiya
# Processing Record 615: Avera
# Processing Record 616: Niimi
# Processing Record 617: Mariestad
# Processing Record 618: Quang Ngai
# Processing Record 619: Bocaiúva

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Export the file into a .csv
City_Weather_df.to_csv("City_Weather.csv", encoding="utf-8", index=False)

# %%
City_Weather_df
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Salinas  36.6777 -121.6555     54.01        81           1
# 1      Necochea -38.5473  -58.7368     61.65        56          71
# 2       Rikitea -23.1203 -134.9692     74.41        81          41
# 3       Ushuaia -54.8000  -68.3000     42.46        56          40
# 4          Chui -33.6971  -53.4616     65.43        57         100
# ..          ...      ...       ...       ...       ...         ...
# 615       Avera  33.1940  -82.5271     62.47        65           0
# 616       Niimi  34.9833  133.4667     51.15        83           8
# 617   Mariestad  58.7097   13.8237     49.37        63          13
# 618  Quang Ngai  15.1167  108.8000     73.13        96         100
# 619    Bocaiúva -17.1078  -43.8150     82.11        41          23
#
#      Wind Speed Country        Date
# 0          3.44      US  1634999287
# 1         10.00      AR  1634999287
# 2         20.94      PF  1634998954
# 3         12.66      AR  1634998899
# 4          3.58      UY  1634999072
# ..          ...     ...         ...
# 615        6.67      US  1634998975
# 616        2.93      JP  1634999416
# 617        2.28      SE  1634999417
# 618        4.79      VN  1634999137
# 619        2.17      BR  1634999417
#
# [620 rows x 9 columns]

# %%
City_Weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  620.000000  620.000000  620.000000  620.000000  620.000000  620.000000
# mean    18.576934   16.313013   56.050500   63.225806   51.570968    7.650710
# std     31.959674   86.693516   27.052058   28.647160   41.343587    6.400365
# min    -54.800000 -179.166700  -12.590000    0.000000    0.000000    0.000000
# 25%     -2.590250  -55.399950   38.535000   49.000000    3.000000    2.925000
# 50%     19.764850   11.895150   61.800000   72.500000   59.000000    6.395000
# 75%     45.229225   88.129200   77.830000   85.000000   96.000000   11.315000
# max     78.218600  179.316700  102.020000  100.000000  100.000000   46.040000

# %%
#Remove cities with missing data
remove_city_data = City_Weather_df[(City_Weather_df["Lat"] != 0)] 
remove_city_data
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Salinas  36.6777 -121.6555     54.01        81           1
# 1      Necochea -38.5473  -58.7368     61.65        56          71
# 2       Rikitea -23.1203 -134.9692     74.41        81          41
# 3       Ushuaia -54.8000  -68.3000     42.46        56          40
# 4          Chui -33.6971  -53.4616     65.43        57         100
# ..          ...      ...       ...       ...       ...         ...
# 615       Avera  33.1940  -82.5271     62.47        65           0
# 616       Niimi  34.9833  133.4667     51.15        83           8
# 617   Mariestad  58.7097   13.8237     49.37        63          13
# 618  Quang Ngai  15.1167  108.8000     73.13        96         100
# 619    Bocaiúva -17.1078  -43.8150     82.11        41          23
#
#      Wind Speed Country        Date
# 0          3.44      US  1634999287
# 1         10.00      AR  1634999287
# 2         20.94      PF  1634998954
# 3         12.66      AR  1634998899
# 4          3.58      UY  1634999072
# ..          ...     ...         ...
# 615        6.67      US  1634998975
# 616        2.93      JP  1634999416
# 617        2.28      SE  1634999417
# 618        4.79      VN  1634999137
# 619        2.17      BR  1634999417
#
# [565 rows x 9 columns]

# %%
remove_city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  565.000000  565.000000  565.000000  565.000000  565.000000  565.000000
# mean    20.385308   17.901005   61.506743   69.380531   56.591150    8.395469
# std     32.925640   90.665368   21.609902   21.746573   39.892065    6.220592
# min    -54.800000 -179.166700  -12.590000    6.000000    0.000000    0.000000
# 25%     -5.809200  -61.748500   46.260000   58.000000   12.000000    3.780000
# 50%     25.716700   22.200000   64.900000   75.000000   71.000000    7.000000
# 75%     47.537800   99.634200   78.640000   86.000000   98.000000   11.540000
# max     78.218600  179.316700  102.020000  100.000000  100.000000   46.040000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
clean_city_data = remove_city_data[(remove_city_data["Humidity"] <=100)]
clean_city_data
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Salinas  36.6777 -121.6555     54.01        81           1
# 1      Necochea -38.5473  -58.7368     61.65        56          71
# 2       Rikitea -23.1203 -134.9692     74.41        81          41
# 3       Ushuaia -54.8000  -68.3000     42.46        56          40
# 4          Chui -33.6971  -53.4616     65.43        57         100
# ..          ...      ...       ...       ...       ...         ...
# 615       Avera  33.1940  -82.5271     62.47        65           0
# 616       Niimi  34.9833  133.4667     51.15        83           8
# 617   Mariestad  58.7097   13.8237     49.37        63          13
# 618  Quang Ngai  15.1167  108.8000     73.13        96         100
# 619    Bocaiúva -17.1078  -43.8150     82.11        41          23
#
#      Wind Speed Country        Date
# 0          3.44      US  1634999287
# 1         10.00      AR  1634999287
# 2         20.94      PF  1634998954
# 3         12.66      AR  1634998899
# 4          3.58      UY  1634999072
# ..          ...     ...         ...
# 615        6.67      US  1634998975
# 616        2.93      JP  1634999416
# 617        2.28      SE  1634999417
# 618        4.79      VN  1634999137
# 619        2.17      BR  1634999417
#
# [565 rows x 9 columns]

# %%
#  Get count and stats for the cities where humidity is less than or equal to 100%
clean_city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  565.000000  565.000000  565.000000  565.000000  565.000000  565.000000
# mean    20.385308   17.901005   61.506743   69.380531   56.591150    8.395469
# std     32.925640   90.665368   21.609902   21.746573   39.892065    6.220592
# min    -54.800000 -179.166700  -12.590000    6.000000    0.000000    0.000000
# 25%     -5.809200  -61.748500   46.260000   58.000000   12.000000    3.780000
# 50%     25.716700   22.200000   64.900000   75.000000   71.000000    7.000000
# 75%     47.537800   99.634200   78.640000   86.000000   98.000000   11.540000
# max     78.218600  179.316700  102.020000  100.000000  100.000000   46.040000

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data.to_csv("cleancitydata.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
values = clean_city_data

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Max Temp"].values
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs Max Temperature (10/22/21)")

#Save file as png
plt.savefig('LatitudevsTemperatureplot.png')

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
values = clean_city_data

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Humidity"].values
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity (10/22/21)")

#Save file as png
plt.savefig('LatitudevsHumidityplot.png')

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
values = clean_city_data

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Cloudiness"].values
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness (10/22/21)")

#Save file as png
plt.savefig('LatitudevsCloudinessplot.png')

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
values = clean_city_data

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Wind Speed"].values
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs Wind Speed (10/22/21)")

#Save file as png
plt.savefig('LatitudevsWindSpeedplot.png')

plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_data_df=clean_city_data[(clean_city_data["Lat"]>0)]

values = north_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Max Temp"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title("Northern Hemisphere - Max Temp vs. Latittude")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('NorthernHemisphere-MaxTempvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.7603358012573451

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_data_df=clean_city_data[(clean_city_data["Lat"]<0)]

values = south_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Max Temp"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title("Southern Hemisphere - Max Temp vs. Latittude")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,45),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('SouthernHemisphere-MaxTempvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.5492075450292625

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_data_df=clean_city_data[(clean_city_data["Lat"]>0)]

values = north_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Humidity"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Northern Hemisphere - Humidity (%) vs. Latittude")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,20),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('NorthernHemisphere-HumidityvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.06607387017112822

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_data_df=clean_city_data[(clean_city_data["Lat"]<0)]

values = south_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Humidity"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Southern Hemisphere - Humidity (%) vs. Latittude")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-57, 30),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('SouthernHemisphere-HumidityvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 2.483851484089187e-05

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_data_df=clean_city_data[(clean_city_data["Lat"]>0)]

values = north_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Cloudiness"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latittude")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(47,25),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('NorthernHemisphere-CloudinessvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.04069366305742362

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_data_df=clean_city_data[(clean_city_data["Lat"]<0)]

values = south_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Cloudiness"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latittude")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('SouthernHemisphere-CloudinessvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.025883720765817634

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_data_df=clean_city_data[(clean_city_data["Lat"]>0)]

values = north_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Wind Speed"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latittude")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,25),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('NorthernHemisphere-WindSpeedvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.00902858426234714

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_data_df=clean_city_data[(clean_city_data["Lat"]<0)]

values = south_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Wind Speed"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latittude")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,30),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('SouthernHemisphere-WindSpeedvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.06462814208566149
