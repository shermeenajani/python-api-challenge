# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 583

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#List to store values
Lat = 0
Lng = 0
Max_Temp = 0
Humidity = 0
Cloudiness = 0
Wind_Speed = 0
Country = ""
Date = ""

City_Weather_df= pd.DataFrame({"City": cities,
                               "Lat": Lat,
                               "Lng": Lng,
                               "Max Temp": Max_Temp,
                               "Humidity": Humidity,
                               "Cloudiness": Cloudiness,
                               "Wind Speed": Wind_Speed,
                               "Country": Country,
                               "Date": Date})

#Loop through cities 
#Incorporate a try-except to skip any cities that are missing a data point.

print(f"Beginning Data Retrieval")
print(f"-----------------------------")
    
for index in range(len(City_Weather_df)):
    city=City_Weather_df.loc[index, "City"]
    #URL to query the api data
    query_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    response = requests.get(query_url).json()
        
    try: 
        print(f"Processing Record {index}: {response['name']}")
        City_Weather_df.loc[index, "City"] = response ["name"]
        City_Weather_df.loc[index, "Lat"] = response ["coord"]["lat"]
        City_Weather_df.loc[index, "Lng"] = response ["coord"]["lon"]
        City_Weather_df.loc[index, "Max Temp"] = response ["main"]["temp_max"]
        City_Weather_df.loc[index, "Humidity"] = response ["main"]["humidity"]
        City_Weather_df.loc[index, "Cloudiness"] = response ["clouds"]["all"]
        City_Weather_df.loc[index, "Wind Speed"] = response ["wind"]["speed"]
        City_Weather_df.loc[index, "Country"] = response ["sys"]["country"]
        City_Weather_df.loc[index, "Date"] = response ["dt"]
        
    except (KeyError, IndexError):
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0: Rikitea
# Processing Record 1: Butaritari
# Processing Record 2: New Norfolk
# Processing Record 3: Ust-Tsilma
# Processing Record 4: Kosonsoy
# Processing Record 5: Cinco Esquinas
# Processing Record 6: Hithadhoo
# Processing Record 7: Ushuaia
# Processing Record 8: Longyearbyen
# Processing Record 9: Geraldton
# Processing Record 10: Korem
# City not found. Skipping...
# Processing Record 12: São João da Barra
# Processing Record 13: Nikolskoye
# Processing Record 14: Alofi
# Processing Record 15: Tiksi
# Processing Record 16: Arlit
# Processing Record 17: Vaini
# Processing Record 18: Port Alfred
# Processing Record 19: Hobart
# Processing Record 20: El Salvador
# Processing Record 21: Aitape
# Processing Record 22: Viedma
# Processing Record 23: Nhulunbuy
# Processing Record 24: Bluff
# Processing Record 25: Aklavik
# Processing Record 26: Bāneh
# Processing Record 27: Puerto Baquerizo Moreno
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Export the file into a .csv
City_Weather_df.to_csv("City_Weather.csv", encoding="utf-8", index=False)

# %%
City_Weather_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Rikitea -23.1203 -134.9692     74.91        79         100
# 1         Butaritari   3.0707  172.7902     81.21        72          40
# 2        New Norfolk -42.7826  147.0587     52.92        60         100
# 3         Ust-Tsilma  65.4410   52.1498     22.80        98          84
# 4           Kosonsoy  41.2561   71.5508     34.36        38           0
# ..               ...      ...       ...       ...       ...         ...
# 578  Verkhnyaya Inta  65.9811   60.3094     21.79        96          77
# 579             Nome  64.5011 -165.4064     32.07        74           1
# 580            Acarí -15.4311  -74.6158     65.46        70          41
# 581    Alice Springs -23.7000  133.8833     78.35        21           7
# 582            Beira -19.8436   34.8389     72.46        83           0
#
#      Wind Speed Country        Date
# 0         19.22      PF  1635043325
# ...

# %%
City_Weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  583.000000  583.000000  583.000000  583.000000  583.000000  583.000000
# mean    18.200012   13.007847   54.046724   67.555746   50.867925    7.010017
# std     32.282287   84.690501   25.880811   27.616605   40.463611    5.547907
# min    -54.800000 -175.200000   -8.930000    0.000000    0.000000    0.000000
# 25%     -3.013350  -55.767200   38.950000   58.000000    6.000000    2.740000
# 50%     17.650000    8.566700   58.820000   76.000000   54.000000    5.880000
# 75%     44.646500   78.820700   75.945000   87.000000   94.000000   10.315000
# max     78.218600  179.316700   98.650000  100.000000  100.000000   31.900000

# %%
#Remove cities with missing data
remove_city_data = City_Weather_df[(City_Weather_df["Lat"] != 0)] 
remove_city_data
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Rikitea -23.1203 -134.9692     74.91        79         100
# 1         Butaritari   3.0707  172.7902     81.21        72          40
# 2        New Norfolk -42.7826  147.0587     52.92        60         100
# 3         Ust-Tsilma  65.4410   52.1498     22.80        98          84
# 4           Kosonsoy  41.2561   71.5508     34.36        38           0
# ..               ...      ...       ...       ...       ...         ...
# 578  Verkhnyaya Inta  65.9811   60.3094     21.79        96          77
# 579             Nome  64.5011 -165.4064     32.07        74           1
# 580            Acarí -15.4311  -74.6158     65.46        70          41
# 581    Alice Springs -23.7000  133.8833     78.35        21           7
# 582            Beira -19.8436   34.8389     72.46        83           0
#
#      Wind Speed Country        Date
# 0         19.22      PF  1635043325
# ...

# %%
remove_city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  532.000000  532.000000  532.000000  532.000000  532.000000  532.000000
# mean    19.944750   14.254840   59.227895   74.031955   55.744361    7.682030
# std     33.277249   88.563842   20.656749   18.856803   39.015551    5.344467
# min    -54.800000 -175.200000   -8.930000   10.000000    0.000000    0.000000
# 25%     -6.146975  -59.656225   45.727500   65.000000   17.000000    3.440000
# 50%     23.714150   18.005450   62.535000   78.000000   67.500000    6.510000
# 75%     47.191625   83.829200   76.465000   88.000000   98.000000   10.815000
# max     78.218600  179.316700   98.650000  100.000000  100.000000   31.900000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
clean_city_data = remove_city_data[(remove_city_data["Humidity"] <=100)]
clean_city_data
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Rikitea -23.1203 -134.9692     74.91        79         100
# 1         Butaritari   3.0707  172.7902     81.21        72          40
# 2        New Norfolk -42.7826  147.0587     52.92        60         100
# 3         Ust-Tsilma  65.4410   52.1498     22.80        98          84
# 4           Kosonsoy  41.2561   71.5508     34.36        38           0
# ..               ...      ...       ...       ...       ...         ...
# 578  Verkhnyaya Inta  65.9811   60.3094     21.79        96          77
# 579             Nome  64.5011 -165.4064     32.07        74           1
# 580            Acarí -15.4311  -74.6158     65.46        70          41
# 581    Alice Springs -23.7000  133.8833     78.35        21           7
# 582            Beira -19.8436   34.8389     72.46        83           0
#
#      Wind Speed Country        Date
# 0         19.22      PF  1635043325
# ...

# %%
#  Get count and stats for the cities where humidity is less than or equal to 100%
clean_city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  532.000000  532.000000  532.000000  532.000000  532.000000  532.000000
# mean    19.944750   14.254840   59.227895   74.031955   55.744361    7.682030
# std     33.277249   88.563842   20.656749   18.856803   39.015551    5.344467
# min    -54.800000 -175.200000   -8.930000   10.000000    0.000000    0.000000
# 25%     -6.146975  -59.656225   45.727500   65.000000   17.000000    3.440000
# 50%     23.714150   18.005450   62.535000   78.000000   67.500000    6.510000
# 75%     47.191625   83.829200   76.465000   88.000000   98.000000   10.815000
# max     78.218600  179.316700   98.650000  100.000000  100.000000   31.900000

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data.to_csv("cleancitydata.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
values = clean_city_data

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Max Temp"].values
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs Max Temperature (10/23/21)")

#Save file as png
plt.savefig('LatitudevsTemperatureplot.png')

plt.show()

# %%
#Analysis: The temperature is higher towards Latitiude=0 and the temp drops as it moves to a higher or lower latitude.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
values = clean_city_data

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Humidity"].values
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity (10/23/21)")

#Save file as png
plt.savefig('LatitudevsHumidityplot.png')

plt.show()

# %%
#Analysis:The scatter plot does not show a pattern between the humidity % and the latitude of the city.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
values = clean_city_data

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Cloudiness"].values
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness (10/23/21)")

#Save file as png
plt.savefig('LatitudevsCloudinessplot.png')

plt.show()

# %%
#Analysis:The scatter plot does not show a pattern between the cloudiness % and the latitude of the city.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
values = clean_city_data

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Wind Speed"].values
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs Wind Speed (10/23/21)")

#Save file as png
plt.savefig('LatitudevsWindSpeedplot.png')

plt.show()

# %%
#Analysis: The scatter plot does not show a pattern between the wind speed (mph) and the latitude of the city. The
#wind speed of 30 mph towards latitude -20 may be a outlier.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_data_df=clean_city_data[(clean_city_data["Lat"]>0)]

values = north_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Max Temp"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title("Northern Hemisphere - Max Temp vs. Latittude (10/23/21)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('NorthernHemisphere-MaxTempvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.7800194852665128

# %%
#Analysis:  The max temp and latitude in the Northern Hemisphere are highly correlated as the r-squared value is 0.78.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_data_df=clean_city_data[(clean_city_data["Lat"]<0)]

values = south_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Max Temp"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title("Southern Hemisphere - Max Temp vs. Latittude (10/23/21)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,45),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('SouthernHemisphere-MaxTempvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.5401343302367394

# %%
#Analysis:The max temp and latitude in the Southern Hemisphere are not as highly correlated 
#as in the Northern Hemipshere.  The r-squared value is 0.54.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_data_df=clean_city_data[(clean_city_data["Lat"]>0)]

values = north_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Humidity"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Northern Hemisphere - Humidity (%) vs. Latittude (10/23/21)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,20),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('NorthernHemisphere-HumidityvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.03117064630457339

# %%
#Analysis:The humidity (%) and latitude in the Northern Hemisphere is not correlated as the r-squared value is 0.03.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_data_df=clean_city_data[(clean_city_data["Lat"]<0)]

values = south_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Humidity"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Southern Hemisphere - Humidity (%) vs. Latittude (10/23/21)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-57, 30),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('SouthernHemisphere-HumidityvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.007054454613061819

# %%
#Analysis:The humidity (%) and latitude in the Southern Hemisphere are also not correlated as 
#the r-squared value is 0.007.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_data_df=clean_city_data[(clean_city_data["Lat"]>0)]

values = north_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Cloudiness"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latittude (10/23/21)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(47,25),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('NorthernHemisphere-CloudinessvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.0344811740656913

# %%
#Analysis:The cloudiness (%) and latitude in the Northern Hemisphere is not correlated as the r-squared value is 0.03.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_data_df=clean_city_data[(clean_city_data["Lat"]<0)]

values = south_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Cloudiness"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latittude (10/23/21)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('SouthernHemisphere-CloudinessvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.06032307808478588

# %%
#Analysis:The cloudiness (%) and latitude in the Southern Hemisphere are also not correlated as 
#the r-squared value is 0.06. Almost twice the value of the Northern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_data_df=clean_city_data[(clean_city_data["Lat"]>0)]

values = north_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Wind Speed"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latittude (10/23/21)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,25),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('NorthernHemisphere-WindSpeedvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.07642702861227986

# %%
#Analysis:The wind speed (mph) and latitude in the Northern Hemisphere is not correlated as the r-squared value is 0.07.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_data_df=clean_city_data[(clean_city_data["Lat"]<0)]

values = south_data_df

#Create Scatter Plot
x_values = values["Lat"].values
y_values = values["Wind Speed"].values
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latittude (10/23/21)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,30),fontsize=15,color="blue")

#Print the r-sqared value
print(f"The r-squared is: {rvalue**2}")

#Save file as png
plt.savefig('SouthernHemisphere-WindSpeedvsLatitudeplot.png')

plt.show()
# Out:
# The r-squared is: 0.021100399637747406

# %%
#Analysis:The wind speed (mpy) and latitude in the Southern Hemisphere is not correlated as the r-squared value is 0.02.
